# %%
# %matplotlib inline
from IPython.display import IFrame

import requests 
from bs4 import BeautifulSoup

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import requests
from bs4 import BeautifulSoup

# %%
# Einlesen der URL 
url = 'https://www.soliver.de/c/damen/sale/schuhe/'


# "requests.get() "holt alle Inhalte von der Website und gibt eine Antwort zurück 
html = requests.get(url)

# %%
# Die Antwort = Response war erfolgreich: 
# 200 = Erfolgreich; 400 = nicht erfolgreich 
html
# Out:
# <Response [200]>

# %%
# soup = Dokument als verschachtelte Datenstruktur dar
# html.text = gibt uns nur den reinen Text aus 
# Der Parser zerlegt die Zeichenkette, um diese Verarbeiten zu können
soup = BeautifulSoup(html.text, 'html.parser')

# %%
# durch den Parser haben wir ein BeautifulSoup-Objekt erhalten 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" itemscope="" itemtype="http://schema.org/WebPage">
#  <head prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <meta content="width=device-width,minimum-scale=1,maximum-scale=5,initial-scale=1" name="viewport"/>
#    <meta content="Mit Schuhen von s.Oliver liegen Frauen voll im Trend. Schuhe in Top-Qualität gibt es im Online Shop von s.Oliver zu kaufen." name="description"/>
#    <title>
#     Damen Schuhe im Sale bei s.Oliver: Reduzierte Schuhe für Damen
#    </title>
#    <meta content="00:44:09 - 28.06.2022" name="robotshreflangtimestamp"/>
#    <link href="https://www.soliver.de/c/damen/sale/schuhe/" hreflang="de-DE" rel="alternate"/>
#    <link href="https://www.soliver.at/c/damen/sale/schuhe/" hreflang="de-AT" rel="alternate"/>
#    <link href="https://www.soliver.hr/c/zene/snizenje/cipele/" hreflang="hr-HR" rel="alternate"/>
#    <link href="https://www.soliver-online.be/c/dames/sale/schoenen/" hreflang="nl-BE" rel="alternate"/>
#    <link href="https://www.soliver-online.be/fr/c/femmes/soldes/chaussures/" hreflang="fr-BE" rel="alternate"/>
#    <link href="https://www.soliver.ch/c/damen/sale/schuhe/" hreflang="de-CH" rel="alternate"/>
#    <link href="https://www.soliver.ch/fr/c/femmes/soldes/chaussures/" hreflang="fr-CH" rel="alternate"/>
#    <link href="https://www.soliver.nl/c/dames/sale/schoenen/" hreflang="nl-NL" rel="alternate"/>
#    <link href="https://www.soliver.fr/c/femmes/soldes/chaussures/" hreflang="fr-FR" rel="alternate"/>
#    <link href="https://www.soliver.si/c/zenske/znizanje/cevlji/" hreflang="sl-SI" rel="alternate"/>
#    <link href="https://www.soliver.cz/c/damy/vyprodej/obuv/" hreflang="cs-CZ" rel="alternate"/>
#    <link href="https://www.soliver.sk/c/damy/sale/obuv/" hreflang="sk-SK" rel="alternate"/>
#    <link href="https://www.soliver.eu/c/women/sale/shoes/" hreflang="x-default" rel="alternate"/>
#    <link href="https://www.soliver.de/c/damen/sale/schuhe/" rel="canonical"/>
#    <meta content="index,follow" name="robots"/>
#    <meta content="on" http-equiv="x-dns-prefetch-control"/>
#    <link href="//fonts.soliver.de" rel="dns-prefetch"/>
#    <link href="//maps.googleapis.com" rel="dns-prefetch"/>
#    <link href="//mediastorage.soliver.com" rel="dns-prefetch"/>
#    <link crossorigin="" href="//fonts.soliver.de/202103/fonts.css?v1656369202142" rel="preconnect"/>
#    <link as="style" href="//fonts.soliver.de/202103/fonts.css?v1656369202142" rel="preload"/>
#    <link href="//fonts.soliver.de/202103/fonts.css?v1656369202142" media="print" onload="this.media='all'" rel="stylesheet"/>
#    <noscript>
#     <link href="//fonts.soliver.de/202103/fonts.css?v1656369202142" rel="stylesheet"/>
#    </noscript>
#    <link crossorigin="" href="//fonts.soliver.de/202103/icons.css?v1656369202142" rel="preconnect"/>
#    <link as="style" href="//fonts.soliver.de/202103/icons.css?v1656369202142" rel="preload"/>
#    <link href="//fonts.soliver.de/202103/icons.css?v1656369202142" media="print" onload="this.media='all'" rel="stylesheet"/>
#    <noscript>
#     <link href="//fonts.soliver.de/202103/icons.css?v1656369202142" rel="stylesheet"/>
#    </noscript>
#    <link crossorigin="" href="//fonts.soliver.de/legacy/icons.css" rel="preconnect"/>
#    <link as="style" href="//fonts.soliver.de/legacy/icons.css" rel="preload"/>
#    <link href="//fonts.soliver.de/legacy/icons.css" media="print" onload="this.media='all'" rel="stylesheet"/>
#    <noscript>
#     <link href="//fonts.soliver.de/legacy/icons.css" rel="stylesheet"/>
#    </noscript>
#    <link as="style" href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/lib/css/allinone-link.css" rel="preload" type="text/css"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/lib/css/allinone-link.css" rel="stylesheet" type="text/css"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/dist/css/production-core.css" rel="stylesheet" type="text/css"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/dist/css/production-soliver.css" rel="stylesheet" type="text/css"/>
#    <link as="style" href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/css/allinone-styles.css" rel="preload" type="text/css"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/css/allinone-styles.css" rel="stylesheet" type="text/css"/>
#    <link as="style" href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/css/soliver-design-system.css" rel="preload" type="text/css"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/css/soliver-design-system.css" rel="stylesheet" type="text/css"/>
#    <link as="image" href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwb1ea90af/so/content/images/favicons/favicon.ico" rel="preload"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwb1ea90af/so/content/images/favicons/favicon.ico" rel="icon"/>
#    <link as="image" href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw400ef207/so/content/images/favicons/icon.svg" rel="preload" type="image/svg+xml"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw400ef207/so/content/images/favicons/icon.svg" rel="icon" type="image/svg+xml"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwaa2eae7a/so/content/images/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw4b0f3fdb/so/content/images/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw625def73/so/content/images/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw79452b73/so/content/images/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw63b21a2e/so/content/images/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw756a95f3/so/content/images/favicons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw28f7324d/so/content/images/favicons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw3021a176/so/content/images/favicons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwf8074fc5/so/content/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwb859f1c2/so/content/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw708753cf/so/content/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dwd10dc8f6/so/content/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#    <link href="/on/demandware.static/Sites-soliverDE-Site/-/default/dw0198301a/so/content/images/favicons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#    <meta content="#000000" name="msapplication-TileColor"/>
#    <meta content="/on/demandware.static/Sites-soliverDE-Site/-/default/dw22a61e35/so/content/images/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/>
#    <meta content="#ffffff" name="theme-color"/>
#    <link as="fetch" href="/manifest.json" rel="preload">
#     <link href="/manifest.json" rel="manifest">
#      <script type="text/javascript">
#       //<!--
# /* <![CDATA[ */
# // Picture element HTML5 shiv
# document.createElement("picture");
# /* ]]> */
# // -->
#      </script>
#      <script src="/on/demandware.store/Sites-soliverDE-Site/de_DE/LocalConstants-Print">
#      </script>
#      <script src="/on/demandware.store/Sites-soliverDE-Site/de_DE/LocalDataNonCached-Print">
#      </script>
#      <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/lib/js/allinone-head.js" type="text/javascript">
#      </script>
#      <script type="text/javascript">
#       //<!--
# /* <![CDATA[ (head-active_data.js) */
# var dw = (window.dw || {});
# dw.ac = {
#     _analytics: null,
#     _events: [],
#     _category: "",
#     _searchData: "",
#     _anact: "",
#     _anact_nohit_tag: "",
#     _analytics_enabled: "true",
#     _timeZone: "Europe/Berlin",
#     _capture: function(configs) {
#         if (Object.prototype.toString.call(configs) === "[object Array]") {
#             configs.forEach(captureObject);
#             return;
#         }
#         dw.ac._events.push(configs);
#     },
# 	capture: function() {
# 		dw.ac._capture(arguments);
# 		// send to CQ as well:
# 		if (window.CQuotient) {
# 			window.CQuotient.trackEventsFromAC(arguments);
# 		}
# 	},
#     EV_PRD_SEARCHHIT: "searchhit",
#     EV_PRD_DETAIL: "detail",
#     EV_PRD_RECOMMENDATION: "recommendation",
#     EV_PRD_SETPRODUCT: "setproduct",
#     applyContext: function(context) {
#         if (typeof context === "object" && context.hasOwnProperty("category")) {
#         	dw.ac._category = context.category;
#         }
#         if (typeof context === "object" && context.hasOwnProperty("searchData")) {
#         	dw.ac._searchData = context.searchData;
#         }
#     },
#     setDWAnalytics: function(analytics) {
#         dw.ac._analytics = analytics;
#     },
#     eventsIsEmpty: function() {
#         return 0 == dw.ac._events.length;
#     }
# };
# /* ]]> */
# // -->
#      </script>
#      <script type="text/javascript">
#       //<!--
# /* <![CDATA[ (head-cquotient.js) */
# var CQuotient = window.CQuotient = {};
# CQuotient.clientId = 'aacp-soliverDE';
# CQuotient.realm = 'AACP';
# CQuotient.siteId = 'soliverDE';
# CQuotient.instanceType = 'prd';
# CQuotient.locale = 'de_DE';
# CQuotient.fbPixelId = '__UNKNOWN__';
# CQuotient.activities = [];
# CQuotient.cqcid='';
# CQuotient.cquid='';
# CQuotient.cqeid='';
# CQuotient.cqlid='';
# /* Turn this on to test against Staging Einstein */
# /* CQuotient.useTest= true; */
# CQuotient.initFromCookies = function () {
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 	  var c = ca[i];
# 	  while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 	  if (c.indexOf('cqcid=') == 0) {
# 		CQuotient.cqcid=c.substring('cqcid='.length,c.length);
# 	  } else if (c.indexOf('cquid=') == 0) {
# 		  var value = c.substring('cquid='.length,c.length);
# 		  if (value) {
# 		  	var split_value = value.split("|", 3);
# 		  	if (split_value.length > 0) {
# 			  CQuotient.cquid=split_value[0];
# 		  	}
# 		  	if (split_value.length > 1) {
# 			  CQuotient.cqeid=split_value[1];
# 		  	}
# 		  	if (split_value.length > 2) {
# 			  CQuotient.cqlid=split_value[2];
# 		  	}
# 		  }
# 	  }
# 	}
# }
# CQuotient.getCQCookieId = function () {
# 	if(window.CQuotient.cqcid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqcid;
# };
# CQuotient.getCQUserId = function () {
# 	if(window.CQuotient.cquid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cquid;
# };
# CQuotient.getCQHashedEmail = function () {
# 	if(window.CQuotient.cqeid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqeid;
# };
# CQuotient.getCQHashedLogin = function () {
# 	if(window.CQuotient.cqlid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqlid;
# };
# CQuotient.trackEventsFromAC = function (/* Object or Array */ events) {
# try {
# 	if (Object.prototype.toString.call(events) === "[object Array]") {
# 		events.forEach(_trackASingleCQEvent);
# 	} else {
# 		CQuotient._trackASingleCQEvent(events);
# 	}
# } catch(err) {}
# };
# CQuotient._trackASingleCQEvent = function ( /* Object */ event) {
# 	if (event && event.id) {
# 		if (event.type === dw.ac.EV_PRD_DETAIL) {
# 			CQuotient.trackViewProduct( {id:'', alt_id: event.id, type: 'raw_sku'} );
# 		} // not handling the other dw.ac.* events currently
# 	}
# };
# CQuotient.trackViewProduct = function(/* Object */ cqParamData){
# 	var cq_params = {};
# 	cq_params.cookieId = CQuotient.getCQCookieId();
# 	cq_params.userId = CQuotient.getCQUserId();
# 	cq_params.emailId = CQuotient.getCQHashedEmail();
# 	cq_params.loginId = CQuotient.getCQHashedLogin();
# 	cq_params.product = cqParamData.product;
# 	cq_params.realm = cqParamData.realm;
# 	cq_params.siteId = cqParamData.siteId;
# 	cq_params.instanceType = cqParamData.instanceType;
# 	cq_params.locale = CQuotient.locale;
#
# 	if(CQuotient.sendActivity) {
# 		CQuotient.sendActivity(CQuotient.clientId, 'viewProduct', cq_params);
# 	} else {
# 		CQuotient.activities.push({activityType: 'viewProduct', parameters: cq_params});
# 	}
# };
# /* ]]> */
# // -->
#      </script>
#      <script async="" crossorigin="anonymous" src="https://soliver.app.baqend.com/v1/file/www/killSpeedKit.js">
#      </script>
#      <meta content="Damen Schuhe im Sale bei s.Oliver: Reduzierte Schuhe für Damen" property="og:title">
#       <meta content="de_DE" property="og:locale">
#        <meta content="c/damen/sale/schuhe" property="og:url">
#         <meta content="Mit Schuhen von s.Oliver liegen Frauen voll im Trend. Schuhe in Top-Qualität gibt es im Online Shop von s.Oliver zu kaufen." property="og:description"/>
#         <style type="text/css">
#          /* START SOLI-25715: Ausblenden der Schaufenster für kleinere Breakpoints */
# #jsMobileDisplayWindow {
# 	display: none;
# }
# /* END SOLI-25715: Ausblenden der Schaufenster für kleinere Breakpoints */
#
# /* START SOLI-52676  */
# .ov__filteroverlay .filterdetails__section[data-filterid="color"],
# .ov__filteroverlay .filterdetails__section[data-filterid="season"] {
# 	display: none;
# }
# /* END SOLI-52676 */
#         </style>
#         <meta content="app-id=680660018" name="apple-itunes-app"/>
#         <meta content="01f0e8e548251ed670d96d11b06b0129" name="p:domain_verify"/>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="pt_productsearchresult js-ovlistview">
#   <span class="jsPageContextData" data-pagecontext="{&quot;global&quot;:{&quot;urlParameter&quot;:{},&quot;availablePages&quot;:{&quot;availabilityreminder&quot;:&quot;availabilityreminder&quot;,&quot;cartaddproduct&quot;:&quot;cartaddproduct&quot;,&quot;cartshow&quot;:&quot;cartshow&quot;,&quot;categoryshow&quot;:&quot;categoryshow&quot;,&quot;cobilling&quot;:&quot;cobilling&quot;,&quot;cocart&quot;:&quot;cocart&quot;,&quot;cocartaddproduct&quot;:&quot;cocartaddproduct&quot;,&quot;cocartaddmultipleproducts&quot;:&quot;cocartaddmultipleproducts&quot;,&quot;cocartremoveproduct&quot;:&quot;cocartremoveproduct&quot;,&quot;cocartchangepersonalization&quot;:&quot;cocartchangepersonalization&quot;,&quot;coconfirmation&quot;:&quot;coconfirmation&quot;,&quot;coregisterconfirmation&quot;:&quot;coregisterconfirmation&quot;,&quot;cologin&quot;:&quot;cologin&quot;,&quot;contactform&quot;:&quot;contactform&quot;,&quot;coshipping&quot;:&quot;coshipping&quot;,&quot;cosummary&quot;:&quot;cosummary&quot;,&quot;dhlpackstationfinder&quot;:&quot;dhlpackstationfinder&quot;,&quot;postatfinder&quot;:&quot;postatfinder&quot;,&quot;errorpage&quot;:&quot;errorpage&quot;,&quot;giftcard&quot;:&quot;giftcard&quot;,&quot;giftcardaddtocart&quot;:&quot;giftcardaddtocart&quot;,&quot;giftcardamount&quot;:&quot;giftcardamount&quot;,&quot;giftcardgreeting&quot;:&quot;giftcardgreeting&quot;,&quot;giftcardtheme&quot;:&quot;giftcardtheme&quot;,&quot;home&quot;:&quot;home&quot;,&quot;department&quot;:&quot;department&quot;,&quot;loginmodal&quot;:&quot;loginmodal&quot;,&quot;myaccountaddressbook&quot;:&quot;myaccountaddressbook&quot;,&quot;myaccountcard&quot;:&quot;myaccountcard&quot;,&quot;myaccountfaq&quot;:&quot;myaccountfaq&quot;,&quot;myaccounthome&quot;:&quot;myaccounthome&quot;,&quot;myaccountlogin&quot;:&quot;myaccountlogin&quot;,&quot;myaccountnewsletter&quot;:&quot;myaccountnewsletter&quot;,&quot;myaccountonlinereturnsconfirmation&quot;:&quot;myaccountonlinereturnsconfirmation&quot;,&quot;myaccountonlinereturnsoverview&quot;:&quot;myaccountonlinereturnsoverview&quot;,&quot;myaccountonlinereturnsreview&quot;:&quot;myaccountonlinereturnsreview&quot;,&quot;myaccountonlinereturnsselectproducts&quot;:&quot;myaccountonlinereturnsselectproducts&quot;,&quot;myaccountonlinereturnsshoworders&quot;:&quot;myaccountonlinereturnshoworders&quot;,&quot;myaccountonlinereturnsstart&quot;:&quot;myaccountonlinereturnsstart&quot;,&quot;myaccountpassword&quot;:&quot;myaccountpassword&quot;,&quot;myaccountpayment&quot;:&quot;myaccountpayment&quot;,&quot;myaccountpoints&quot;:&quot;myaccountpoints&quot;,&quot;myaccountprofile&quot;:&quot;myaccountprofile&quot;,&quot;myaccountwishlist&quot;:&quot;myaccountwishlist&quot;,&quot;myaccountwishlistadd&quot;:&quot;myaccountwishlistadd&quot;,&quot;myaccountwishlistremove&quot;:&quot;myaccountwishlistremove&quot;,&quot;myaccountwishlistcartadd&quot;:&quot;myaccountwishlistcartadd&quot;,&quot;newsletter&quot;:&quot;newsletter&quot;,&quot;page&quot;:&quot;page&quot;,&quot;productdetails&quot;:&quot;productdetails&quot;,&quot;productquickview&quot;:&quot;productquickview&quot;,&quot;productsearch&quot;:&quot;productsearch&quot;,&quot;retailstoreinventory&quot;:&quot;retailstoreinventory&quot;,&quot;retailstoreinventorydetail&quot;:&quot;retailstoreinventorydetail&quot;,&quot;retailstoreinventoryresult&quot;:&quot;retailstoreinventoryresults&quot;,&quot;retailstoreinventorysearch&quot;:&quot;retailstoreinventorysearch&quot;,&quot;storelocator&quot;:&quot;storelocator&quot;,&quot;stores&quot;:&quot;stores&quot;,&quot;wishlistadd&quot;:&quot;wishlistadd&quot;,&quot;wishlistremove&quot;:&quot;wishlistremove&quot;},&quot;webview&quot;:{&quot;requireAuthGlobal&quot;:false},&quot;recommendations&quot;:[],&quot;instanceType&quot;:&quot;prd&quot;,&quot;systemcodeversion&quot;:&quot;RC22_13_21&quot;,&quot;constants&quot;:{&quot;site&quot;:{&quot;id&quot;:&quot;soliverDE&quot;,&quot;name&quot;:&quot;s.Oliver DE&quot;},&quot;url&quot;:{&quot;googleMapsSc ...
#   </span>
#   <span class="jsPageContextData" data-pagecontext='{"global":{"urlParameter":{},"navigationTree":[{"cgid":"women","level":1,"url":"/c/damen/","name":"Damen","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_new","level":2,"url":"/c/damen/new/","name":"New","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_new_brandnew","level":3,"url":"/c/damen/new/brand-new/","name":"Brand Neu (1-3 Tage)","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_oberteile","level":3,"url":"/c/damen/new/oberteile/","name":"Oberteile","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_unterteile","level":3,"url":"/c/damen/new/unterteile/","name":"Unterteile","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_kleider","level":3,"url":"/c/damen/new/kleider-jumpsuits/","name":"Kleider &amp; Jumpsuits","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_schuhe","level":3,"url":"/c/damen/new/schuhe/","name":"Schuhe","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_accessories","level":3,"url":"/c/damen/new/accessoires/","name":"Accessoires","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_new_bodywear","level":3,"url":"/c/damen/new/bodywear/","name":"Unterwäsche &amp; Bademode","isParent":false,"showAllProducts":false,"childs":[]}]},{"cgid":"wo_komplett","level":2,"url":"/c/damen/bekleidung/","name":"Bekleidung","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_ko_top_seller","level":3,"url":"/c/damen/bekleidung/bestseller/","name":"Unsere Bestseller","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_tshirts","level":3,"url":"/c/damen/bekleidung/t-shirts/","name":"Shirts &amp; Tops","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_ko_ts_tshirts","level":4,"url":"/c/damen/bekleidung/t-shirts/t-shirts/","name":"T-Shirts","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ts_tops","level":4,"url":"/c/damen/bekleidung/t-shirts/tops/","name":"Tops","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ts_fashion_lang","level":4,"url":"/c/damen/bekleidung/t-shirts/langarm/","name":"Longsleeves","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ts_dreiviertel","level":4,"url":"/c/damen/bekleidung/t-shirts/dreiviertel-arm/","name":"3/4 Arm","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ts_poloshirts","level":4,"url":"/c/damen/bekleidung/t-shirts/poloshirts/","name":"Poloshirts","isParent":false,"showAllProducts":false,"childs":[]}]},{"cgid":"wo_ko_kleider","level":3,"url":"/c/damen/bekleidung/kleider/","name":"Kleider","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_ko_kl_mini","level":4,"url":"/c/damen/bekleidung/kleider/mini/","name":"Mini","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_kl_midi","level":4,"url":"/c/damen/bekleidung/kleider/midi/","name":"Midi","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_kl_maxi","level":4,"url":"/c/damen/bekleidung/kleider/maxi/","name":"Maxi","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_kl_hochzeiten_feste","level":4,"url":"/c/damen/bekleidung/kleider/abendkleider/","name":"Hochzeiten &amp; Feste","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_kl_business","level":4,"url":"/c/damen/bekleidung/kleider/business/","name":"Business","isParent":false,"showAllProducts":false,"childs":[]}]},{"cgid":"wo_ko_hosen","level":3,"url":"/c/damen/bekleidung/hosen/","name":"Hosen","isParent":true,"showAllProducts":false,"childs":[{"cgid":"wo_ko_ho_casual","level":4,"url":"/c/damen/bekleidung/hosen/casual/","name":"Casual","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ho_business","level":4,"url":"/c/damen/bekleidung/hosen/business/","name":"Business","isParent":false,"showAllProducts":false,"childs":[]},{"cgid":"wo_ko_ho_chinos","level":4,"url":"/c/damen/bekleidung ...
#   </span>
#   <div class="svg-icons" style="display: none;">
#    <svg viewbox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#     <style>
#      :root>svg{display:none}:root>svg:target{display:block}
#     </style>
#     <svg id="icon-cross" viewbox="0 0 1000 1000">
#      <path d="M1000 68L932 0 500 432 68 0 0 68l432 432L0 932l68 68 432-432 432 432 68-68-432-432z">
#      </path>
#     </svg>
#     <svg id="icon-info" viewbox="0 0 999.79156 1000">
#      <path d="M493.13 0C217.108 3.793-3.745 230.68.048 506.874c3.276 275.85 230.335 496.703 506.443 493.082 276.024-3.707 496.962-230.593 493.256-506.702C995.522 217.232 768.806-3.62 492.958.172zm42.24 141.804c70.17 0 90.944 40.688 90.944 87.238 0 58.1-46.55 111.89-125.857 111.89-66.55 0-98.1-33.446-96.29-88.615 0-46.55 38.965-110.513 131.29-110.513zM415.03 825.826c-37.067 0-64.05-22.413-38.188-121.03l42.412-174.992c7.327-28.016 8.62-39.222 0-39.222-11.207 0-59.05 19.827-87.41 38.79l-18.103-30.17c89.652-74.996 193.096-118.96 237.922-118.96 37.067 0 43.1 43.964 25 111.202l-49.137 183.613c-8.62 32.757-4.31 43.963 4.31 43.963 11.207 0 47.412-12.93 82.755-41.377l21.55 28.447c-87.926 87.065-182.75 120.684-219.817 120.684z">
#      </path>
#     </svg>
#     <svg id="icon-menu" viewbox="0 0 1000 750">
#      <path d="M0 0h1000v125H0V0zm0 312.5h1000v125H0v-125zM0 625h1000v125H0V625z">
#      </path>
#     </svg>
#     <svg id="logo-soliver" viewbox="0 320.8 595.5 200.3">
#      <path d="M388.6 418.6c5.5 0 9.6 2.9 9.3 8.2-2 31.4 1.2 73.6 12.5 73.6 7.9 0 16.6-25.3 20.1-53.6-5.2-8.2-8.2-18-8.2-28.5 0-13.4 4.7-18.3 9.9-18.3s8.4 7.3 8.7 17.5c.3 7.6-.3 17.5-1.5 27.7 4.1 6.1 9.3 10.2 15.1 13.1 1.2-30.3 15.4-54.4 34.1-54.4 13.1 0 24.5 9.3 24.5 31.4s-16.6 34.9-34.9 34.9c-2 0-4.1 0-6.1-.3.9 23.9 6.4 37.8 20.7 37.8 24.2 0 37.3-39.9 37.8-79.8-4.4-2.9-7.6-7-7.9-12.2-.6-7.6 3.2-12.2 7.9-12.2 5.8 0 8.2 5.8 8.2 13.4v5.5c5.2 2.3 11.6 1.2 16 0 11.6-3.2 21-2.3 16 18.9-9.3 39.9-13.1 65.2 3.2 65.2 8.2 0 13.7-7.3 15.4-10.8 2.6-4.7 7.9-.9 5.5 3.8-4.1 8.2-12.2 16-24.7 16-16.6 0-24.2-13.4-23.3-33.8.6-14.6 3.2-28.5 6.4-43.7 1.5-7.6-7.9-5.8-14.6-7-2.3 48.3-16.9 84.4-48 84.4-20.4 0-34.9-16.3-35.8-49.8-6.4-2.6-11.9-6.1-16.6-10.2-4.7 29.4-14.8 60-29.4 60-10.5 0-18-10.2-23.3-26.2-4.9 16-13.1 26.2-25.3 26.2-13.4 0-24.2-13.1-26.2-38.7-6.1 21-16.3 38.7-33.8 38.7-11.1 0-27.7-7.9-34.3-40.8-4.4 1.5-8.4 2.3-11.9 2.6-6.4.6-6.4-5.5-1.7-6.4 4.1-.6 8.2-1.7 12.5-3.5-1.5-11.1-2-24.5-1.2-40.5 3.8-63.2 22.4-91.7 39.9-91.1 14.8.6 22.4 17.5 20.4 43.1-3.8 48.3-23 74.8-41.9 87.9 2 23 8.2 38.4 21.2 38.4 18.6 0 29.7-44.5 31.7-85.9.3-4.9 5.8-6.4 9.3-6.4 5.5 0 9.9 2.9 9 8.7-6.4 53.6-4.7 83.8 10.2 83.8 9.9 0 16-18 17.8-33.8-2-13.1-2.9-28.2-2.6-44.5.3-6.1 5.2-8.4 9.9-8.4m83.3 44c2 .3 4.4.3 6.4.3 14.8 0 24.2-10.8 24.2-26.2 0-9.6-3.5-19.8-12.5-19.8-11.4-.3-17.9 20.6-18.1 45.7M281.5 457c16.3-14.3 30.6-39 32.6-76.8.9-16.3-.9-30.3-8.4-30.6-9.6-.3-21.2 23.3-23.9 77.7-.6 10.8-.9 20.7-.3 29.7M34.6 403.5c23 0 29.1 17.5 27.1 27.7-.9 4.4-6.4 4.7-6.7 0-.6-6.1-5.2-16.6-17.2-17.2-8.4-.6-14.8 4-14.8 13.6 0 22.7 44.8 25.3 44.8 57.3 0 16.9-15.1 30.6-34.3 30.6-25.3.3-35.2-16.5-33.2-30.2 1.2-7.3 8.7-7 8.4-.9-.3 9 6.1 21 20.7 21 12.5 0 20.4-7 20.4-18.6 0-21-44.5-25-44.5-56.5-.1-17.2 14.8-26.8 29.3-26.8m302.2-23.9c0-6.1 4.7-11.1 10.2-11.1 5.8 0 10.2 4.9 10.2 11.1 0 6.1-4.7 11.1-10.2 11.1-5.6 0-10.2-5-10.2-11.1M81.2 504.5c0-6.1 4.9-11.1 11.1-11.1 6.1 0 11.1 4.9 11.1 11.1s-4.9 11.1-11.1 11.1c-5.8.2-11.1-5-11.1-11.1m99.9 16.6c-61.1.6-82.7-60.8-80.9-100.1 2.6-65.5 44-105.4 94.3-99.6 4.4.6 4.7 5.2 0 5.2-52.4-.9-70.7 49.5-70.2 95.5.6 47.7 19.5 90.2 57.1 89.9 32.9-.3 47.2-41 49.5-79.8 2.9-46.3-12.8-89.1-38.1-88.2-25.6.6-36.7 32-35.5 57.6 1.2 33.8 20.4 50.9 27.1 56.2 2 1.7.6 5.2-3.2 4.4-9.9-2.3-38.4-19.5-39.9-61.4-1.5-38.1 22.1-65.5 52.7-65.8 31.7-.3 59.7 34.3 57.1 95.5-4 60-35.1 90-70 90.6" fill="#B80028">
#      </path>
#     </svg>
#    </svg>
#   </div>
#   <header class="m-header app--hidden" data-ds-header="">
#    <div class="m-header__dimmer" data-ds-event='{"type":"dsEvent:CompactSearch:Close"}'>
#    </div>
#    <div class="m-header__spacer" data-ds-header-spacer="">
#    </div>
#    <div class="m-header__inner" data-ds-header-inner="">
#     <div class="m-header__top" data-ds-header-top="">
#      <div class="contentasset" data-cid="BAR_INFO_SPECIALOLYMPICS" data-configuration="">
#       <div class="m-header__promotionBar">
#        <div class="c-benefitsBar u-hidden@xs-to-m" style="background: #8c8b8a; color: #fff">
#         <a class="jsClickTrack" data-clicktracking='{"econda": {"target": {"group": "Promotion Bar", "name": "BAR_INFO_SPECIALOLYMPICS: LP_SPECIALOLYMPICS", "value": 1, "calc": "a"}}}' href="https://www.soliver.de/special-olympics-LP_SPECIALOLYMPICS.html">
#          <ul class="c-list c-list--horizontal">
#           <li class="c-list__item">
#            <div class="c-list__itemContent">
#             <p class="o-copy o-copy--sizeXS">
#              <span>
#               s.Oliver X Special Olympics Deutschland
#               <u>
#                Mehr erfahren
#               </u>
#              </span>
#             </p>
#            </div>
#           </li>
#          </ul>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="m-header__middle">
#      <div class="m-header__middleInner">
#       <div class="m-header__left">
#        <div class="m-header__mainNavigation">
#         <div class="contentasset" data-cid="HEADER_CATEGORY_NAVIGATION_CHANGE" data-configuration="">
#          <nav class="c-mainNavigation" data-ds-mainnavigation="" data-so-navigation-tracking="">
#           <div class="c-mainNavigation__inner c-mainNavigation__inner--categoryLevel1">
#            <ul class="c-mainNavigation__list c-mainNavigation__list--categoryLevel1">
#             <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel1 jsDepartmentLink" data-so-navigation-tracking-item="" data-topnav-id="women">
#              <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel1" data-so-navigation-tracking-link="women" href="https://www.soliver.de/c/damen/">
#               Damen
#              </a>
#              <div class="c-mainNavigation__inner c-mainNavigation__inner--categoryLevel2">
#               <ul class="c-mainNavigation__list c-mainNavigation__list--categoryLevel2" data-ds-mainnavigation-list="">
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_new">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_new" href="https://www.soliver.de/c/damen/new/">
#                  New
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width8/12@l-to-xl u-width9/12@xl-up">
#                       <div data-so-navigation-tracking-item="">
#                        <a class="c-flyout__categoryTitle" data-so-navigation-tracking-link="wo_new" href="https://www.soliver.de/c/damen/new/">
#                         New
#                        </a>
#                       </div>
#                       <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                        <div class="u-width12/12 jsRenderNavList" data-cgid="wo_new" data-depth="2">
#                        </div>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_new_brandnew" href="https://www.soliver.de/c/damen/new/brand-new/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw6e01b26e/contentassets/2021/navigation/flyouts/women/wo_new_01.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Brand Neu
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="c-mainNavigation__flyoutClose">
#                   <div class="c-mainNavigation__flyoutCloseButton" data-ds-mainnavigation-close="">
#                   </div>
#                  </div>
#                 </div>
#                </li>
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_komplett">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_komplett" href="https://www.soliver.de/c/damen/bekleidung/">
#                  Bekleidung
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width8/12@l-to-xl u-width6/12@xl-up">
#                       <div data-so-navigation-tracking-item="">
#                        <a class="c-flyout__categoryTitle" data-so-navigation-tracking-link="wo_komplett" href="https://www.soliver.de/c/damen/bekleidung/">
#                         Bekleidung
#                        </a>
#                       </div>
#                       <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                        <div class="u-width4/12@l-up jsRenderNavList" data-cgid="wo_komplett" data-depth="2" data-end="13">
#                        </div>
#                        <div class="u-width4/12@l-up jsRenderNavList" data-cgid="wo_komplett" data-depth="2" data-start="14">
#                        </div>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_ko_kleider" href="https://www.soliver.de/c/damen/bekleidung/kleider/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw15be074d/contentassets/2021/navigation/flyouts/women/wo_bekleidung_01.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Kleider
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="u-hidden@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_ko_blusen" href="https://www.soliver.de/c/damen/bekleidung/blusen/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw85a6e357/contentassets/2021/navigation/flyouts/women/wo_bekleidung_02.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Blusen
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="c-mainNavigation__flyoutClose">
#                   <div class="c-mainNavigation__flyoutCloseButton" data-ds-mainnavigation-close="">
#                   </div>
#                  </div>
#                 </div>
#                </li>
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_schuhe">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_schuhe" href="https://www.soliver.de/c/damen/schuhe/">
#                  Schuhe
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width4/12@l-to-xl u-width6/12@xl-up">
#                       <div data-so-navigation-tracking-item="">
#                        <a class="c-flyout__categoryTitle" data-so-navigation-tracking-link="wo_schuhe" href="https://www.soliver.de/c/damen/schuhe/">
#                         Schuhe
#                        </a>
#                       </div>
#                       <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                        <div class="u-width12/12@l-up jsRenderNavList" data-cgid="wo_schuhe" data-depth="2">
#                        </div>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_sc_sneaker" href="https://www.soliver.de/c/damen/schuhe/sneaker/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw44248f01/contentassets/2021/navigation/flyouts/women/wo_schuhe_01.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Sneaker
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_sc_sandalen" href="https://www.soliver.de/c/damen/schuhe/sandalen/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dwe58fddc7/contentassets/2021/navigation/flyouts/women/wo_schuhe_02.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Sandalen &amp; Pantoletten
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="c-mainNavigation__flyoutClose">
#                   <div class="c-mainNavigation__flyoutCloseButton" data-ds-mainnavigation-close="">
#                   </div>
#                  </div>
#                 </div>
#                </li>
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_accessoires">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_accessoires" href="https://www.soliver.de/c/damen/accessoires/">
#                  Accessoires
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width4/12@l-to-xl u-width6/12@xl-up">
#                       <div data-so-navigation-tracking-item="">
#                        <a class="c-flyout__categoryTitle" data-so-navigation-tracking-link="wo_accessoires" href="https://www.soliver.de/c/damen/accessoires/">
#                         Accessoires
#                        </a>
#                       </div>
#                       <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                        <div class="u-width12/12@l-up jsRenderNavList" data-cgid="wo_accessoires" data-depth="2">
#                        </div>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_ac_schmuck" href="https://www.soliver.de/c/damen/accessoires/echtschmuck/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dwbc731c4d/contentassets/2021/navigation/flyouts/women/wo_acc_011.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Echtschmuck
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_ac_taschen" href="https://www.soliver.de/c/damen/accessoires/taschen/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw8cfa6c5e/contentassets/2021/navigation/flyouts/women/wo_acc_022.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Taschen
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="c-mainNavigation__flyoutClose">
#                   <div class="c-mainNavigation__flyoutCloseButton" data-ds-mainnavigation-close="">
#                   </div>
#                  </div>
#                 </div>
#                </li>
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_duefte">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_duefte" href="https://www.soliver.de/c/damen/duefte-pflege/">
#                  Düfte &amp; Pflege
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width8/12@l-to-xl u-width9/12@xl-up">
#                       <div data-so-navigation-tracking-item="">
#                        <a class="c-flyout__categoryTitle" data-so-navigation-tracking-link="wo_duefte" href="https://www.soliver.de/c/damen/duefte-pflege/">
#                         Düfte &amp; Pflege
#                        </a>
#                       </div>
#                       <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                        <div class="u-width12/12@l-up jsRenderNavList" data-cgid="wo_duefte" data-depth="2">
#                        </div>
#                       </div>
#                      </div>
#                      <div class="u-width4/12@l-to-xl u-width3/12@xl-up">
#                       <div class="c-contentPanel" data-so-navigation-tracking-item="">
#                        <a class="c-contentPanel__link" data-so-navigation-tracking-link="Image wo_duefte" href="https://www.soliver.de/c/damen/duefte-pflege/">
#                         <div class="c-contentPanel__image">
#                          <div class="o-image o-image--portrait" data-ds-picture='{"sources":[],"default":"https://www.soliver.de/on/demandware.static/-/Library-Sites-soliverALL/default/dw21f5d922/contentassets/2021/navigation/flyouts/women/wo_duefte_01.jpg"}'>
#                          </div>
#                         </div>
#                         <div class="c-contentPanel__content c-contentPanel__content--bottom">
#                          <button class="o-button o-button-m o-button--inverted o-button--expanded">
#                           Düfte
#                          </button>
#                         </div>
#                        </a>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="c-mainNavigation__flyoutClose">
#                   <div class="c-mainNavigation__flyoutCloseButton" data-ds-mainnavigation-close="">
#                   </div>
#                  </div>
#                 </div>
#                </li>
#                <li class="c-mainNavigation__listItem c-mainNavigation__listItem--categoryLevel2 jsDepartmentLink" data-ds-mainnavigation-item="" data-so-navigation-tracking-item="" data-topnav-id="wo_marken">
#                 <a class="c-mainNavigation__listLink c-mainNavigation__listLink--categoryLevel2" data-ds-mainnavigation-link="" data-so-navigation-tracking-link="wo_marken" href="https://www.soliver.de/c/damen/marken/">
#                  Marken
#                 </a>
#                 <div class="c-mainNavigation__flyout">
#                  <div class="c-flyout" data-mms-dl="flyout_navigation">
#                   <div class="c-flyout__inner c-flyout__inner--categoryLevel3">
#                    <div class="c-flyout__grid">
#                     <div class="u-grid u-grid--gutterH10 u-grid--gutterV10 u-grid--gutterH15@m-up u-grid--gutterV15@m-up">
#                      <div class="u-width6/12@l-up">
#                       <div data-so-navigation-tracking-item="">
# ...
# 				{{:imprintLink}}
# 			</a> |
# 			<a href="/datenschutzbestimmungen-GENERAL_PRIVACY.html" class="o-link ta_consentLayer_privacy2">
# 				{{:privacyLink}}
# 			</a>
# 		</span>
# 		</div>
# 	</div>
# </div>
#   </script>
#   <script data-fg-consent-template="fg-consent-second-layer" type="text/x-jsrender">
#    <div class="fg-consentlayer fg-furtherlayer fg-furtherlayer--second{{if isActive}} is-active{{/if}}">
# 	<div class="fg-furtherlayer__body">
# 		<div class="fg-furtherlayer__scroll" data-fg-consent-scroll>
# 			<div class="fg-furtherlayer__content">
# 				<div class="fg-furtherlayer__breadcrumbs c-breadcrumbs">
# 					<div class="c-breadcrumbs__inner">
# 						<span class="c-breadcrumbs__path">
# 							<a data-fg-consent-showprevious href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								Privatsph&auml;re
# 							</a>
# 						</span>
# 						<span class="c-breadcrumbs__path">
# 							<a href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								Einstellungen
# 							</a>
# 						</span>
# 					</div>
# 				</div>
# 				<div class="fg-furtherlayer__headline o-headline o-headline--sizeXS">
# 					Deine Privatsph&auml;re-Einstellungen
# 				</div>
# 				<div class="fg-furtherlayer__generalCopy o-copy o-copy--sizeXXS">
# 					{{:generalInfoText}}
# 				</div>
# 				<div class="fg-furtherlayer__box">
# 					<div class="fg-furtherlayer__switch">
# 						<label class="fg-switch">
# 							<span class="o-subline o-subline--sizeM">
# 								Alle aktivieren
# 							</span>
# 							<input name="toggleall" {{if numberOfCheckedCategories == numberOfTotalCategories}}checked{{/if}} type="checkbox" data-fg-consent-toggle class="fg-switch__input">
# 						</label>
# 					</div>
# 					<div data-fg-consent-total class="fg-furtherlayer__copy o-copy o-copy--sizeXXS {{if numberOfCheckedCategories == numberOfTotalCategories}}u-hidden{{/if}}">
# 						<span>{{:numberOfCheckedCategories}}</span> von <span>{{:numberOfTotalCategories}}</span> Einstellungen aktiv
# 					</div>
# 				</div>
#
# 				{{for categories}}
# 				<div class="fg-furtherlayer__box">
# 					<div class="fg-furtherlayer__switch">
# 						<label class="fg-switch">
# 							<span class="o-subline o-subline--sizeM">
# 								{{:name}}
# 							</span>
# 							<input data-fg-consent-input name="{{:slug}}" {{if isEssential}}disabled{{/if}} {{if status }}checked{{/if}} type="checkbox" class="fg-switch__input">
# 						</label>
# 						<div data-fg-consent-total class="fg-furtherlayer__copy fg-furtherlayer__copy--marginBottom o-copy o-copy--sizeXXS {{if numberOfCheckedServices == numberOfTotalServices || numberOfCheckedServices == 0}}u-hidden{{/if}}">
# 							<span>{{:numberOfCheckedServices}}</span> von <span>{{:numberOfTotalServices}}</span> Einstellungen aktiv
# 						</div>
# 					</div>
# 					<div class="fg-furtherlayer__copy o-copy o-copy--sizeXXS">
# 						{{:description}}
# 					</div>
# 					<a href="javascript:;" class="fg-furtherlayer__link o-link o-link--underlined o-link--sizeXXS" data-fg-consent-service data-fg-consent-category="{{:slug}}">
# 						Technologien anzeigen
# 					</a>
# 				</div>
# 				{{/for}}
#
# 			</div>
# 		</div>
# 		<div class="fg-furtherlayer__footer">
# 				<a href="javascript:;" class="o-button o-button--inverted o-button--withBorder o-button--expanded" data-fg-consent-btn data-fg-consent-action="saveSettings">
# 					Einstellungen speichern
# 				</a>
# 				<a href="javascript:;" class="o-button o-button--expanded" data-fg-consent-btn data-fg-consent-action="acceptAll">
# 					Alles aktivieren und speichern
# 				</a>
# 		</div>
# 	</div>
# </div>
#   </script>
#   <script data-fg-consent-template="fg-consent-third-layer" type="text/x-jsrender">
#    <div class="fg-consentlayer fg-furtherlayer fg-furtherlayer--third{{if isActive}} is-active{{/if}}">
# 	<div class="fg-furtherlayer__body">
# 		<div class="fg-furtherlayer__scroll" data-fg-consent-scroll>
# 			<div class="fg-furtherlayer__content">
# 				<div class="fg-furtherlayer__breadcrumbs c-breadcrumbs">
# 					<div class="c-breadcrumbs__inner">
# 						<span class="c-breadcrumbs__path">
# 							<a data-fg-consent-showprevious href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								Einstellungen
# 							</a>
# 						</span>
# 						<span class="c-breadcrumbs__path">
# 							<a href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								{{:breadcrumb.path2}}
# 							</a>
# 						</span>
# 					</div>
# 				</div>
# 				<div class="fg-furtherlayer__headline o-headline o-headline--sizeXS">
# 					{{:headline}}
# 				</div>
# 				<div class="fg-furtherlayer__box">
# 					<div class="fg-furtherlayer__switch">
# 						<label class="fg-switch">
# 							<span class="o-subline o-subline--sizeM">
# 								Alle aktivieren
# 							</span>
# 							<input {{if isEssential}}disabled{{/if}}
#               {{if numberOfCheckedServices == numberOfTotalServices}}checked{{/if}} data-fg-consent-toggle name="toggleall" type="checkbox" class="fg-switch__input">
# 						</label>
# 					</div>
# 					<div data-fg-consent-total class="fg-furtherlayer__copy o-copy o-copy--sizeXXS {{if numberOfCheckedServices == numberOfTotalServices || numberOfCheckedServices == 0}}u-hidden{{/if}}">
# 						<span>{{:numberOfCheckedServices}}</span> von <span>{{:numberOfTotalServices}}</span> Einstellungen aktiv
# 					</div>
# 				</div>
#
# 				{{for services}}
# 				<div class="fg-furtherlayer__box">
# 					<div class="fg-furtherlayer__switch">
# 						<label class="fg-switch">
# 							<span class="o-subline o-subline--sizeM">
# 								{{:name}}
# 							</span>
# 							<input data-fg-consent-input name="{{:name}}" {{if isEssential}}disabled{{/if}} {{if status }}checked{{/if}} type="checkbox" class="fg-switch__input">
# 						</label>
# 					</div>
# 					<div class="fg-furtherlayer__copy o-copy o-copy--sizeXXS">
# 						{{:description}}
# 					</div>
# 					<a href="javascript:;" data-fg-consent-info data-fg-consent-service="{{:id}}" class="fg-furtherlayer__link o-link o-link--underlined o-link--sizeXXS">
# 						Weitere Informationen
# 					</a>
# 				</div>
# 				{{/for}}
# 			</div>
# 		</div>
# 	</div>
# </div>
#   </script>
#   <script data-fg-consent-template="fg-consent-fourth-layer" type="text/x-jsrender">
#    <div class="fg-consentlayer fg-furtherlayer fg-furtherlayer--fourth">
# 	<div class="fg-furtherlayer__body">
# 		<div class="fg-furtherlayer__scroll">
# 			<div class="fg-furtherlayer__content">
# 				<div class="fg-furtherlayer__breadcrumbs c-breadcrumbs">
# 					<div class="c-breadcrumbs__inner">
# 						<span data-fg-consent-showprevious class="c-breadcrumbs__path">
# 							<a href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								{{:breadcrumb.path1}}
# 							</a>
# 						</span>
# 						<span class="c-breadcrumbs__path">
# 							<a href="javascript:;" class="o-link o-link--sizeXXS c-breadcrumbs__link">
# 								{{:breadcrumb.path2}}
# 							</a>
# 						</span>
# 					</div>
# 				</div>
# 				<div class="fg-furtherlayer__headline o-headline o-headline--sizeXS">
# 					{{:headline}}
# 				</div>
# 				<div class="fg-furtherlayer__switch">
# 					<label class="fg-switch">
# 						<span class="o-copy o-copy--sizeXXS">
# 							{{:description}}
# 						</span>
# 						<input data-fg-consent-input name="{{:name}}" {{if isEssential}}disabled{{/if}} {{if status }}checked{{/if}} type="checkbox" class="fg-switch__input">
# 					</label>
# 				</div>
# 				{{if processingCompanyName}}
# 				<div class="fg-furtherlayer__semibox">
# 					<div class="o-subline o-subline--sizeM">
# 						{{:processingCompanyTitle}}
# 					</div>
# 					<div class="u-marginTopXXS o-copy o-copy--sizeXXS o-copy--bold">
# 						{{:processingCompanyName}}
# 					</div>
# 					<div class="o-copy o-copy--sizeXXS">
# 						{{:processingCompanyAdress}}
# 					</div>
# 					<div class="u-marginTopXS o-copy o-copy--sizeXXS">
# 						{{:dataProtectionOfficerTitle}}<br />
# 						{{:dataProtectionOfficer}}
# 					</div>
# 				</div>
# 				{{/if}}
# 				{{if serviceInfos}}
# 				{{for serviceInfos}}
# 				<div class="fg-furtherlayer__semibox">
# 					<div class="o-subline o-subline--sizeM">
# 						{{:title}}
# 					</div>
# 					<div class="u-marginTopXS o-copy o-copy--sizeXXS">
# 						{{:description}}
# 					</div>
# 					{{if items}}
# 					<div class="fg-furtherlayer__taglist">
# 						{{for items}}
# 						<span class="fg-tag {{if #parent.parent.data.expanded}}fg-tag--expanded {{/if}}o-copy o-copy--sizeXXS o-copy--bold">
# 							{{:}}
# 						</span>
# 						{{/for}}
# 					</div>
# 					{{/if}}
# 					{{if links}}
# 					{{for links}}
# 					<div class="u-marginTopXS o-copy o-copy--sizeXXS">
# 						{{:title}}
# 					</div>
# 					<a target="_blank" rel="noopener" href="{{:href}}" class="o-link o-link--underlined o-link--sizeXXS">
# 						{{:href}}
# 					</a>
# 					{{/for}}
# 					{{/if}}
# 				</div>
# 				{{/for}}
# 				{{/if}}
# 				{{if cookieData}}
# 				<div class="fg-furtherlayer__semibox">
# 					<div class="o-subline o-subline--sizeM">
# 						{{:cookieData.title}}
# 					</div>
# 					<div class="u-marginTopXS o-copy o-copy--sizeXXS">
# 						{{:cookieData.description}}
# 					</div>
# 					<div class="u-marginTopXS o-copy o-copy--sizeXXS">
# 						{{:cookieData.infoPart1}}
# 					</div>
# 					<div class="o-copy o-copy--sizeXXS">
# 						{{:cookieData.infoPart2}}
# 					</div>
# 				</div>
# 				{{/if}}
# 				{{if history}}
# 				<div class="fg-furtherlayer__semibox">
# 					<div class="o-subline o-subline--sizeM">
# 						{{:history.title}}
# 					</div>
# 					<div class="u-marginTopXS">
# 						<div class="o-copy o-copy--bold o-copy--sizeXXS">{{:history.controllerIdLabel}}</div>
# 						<div class="o-copy o-copy--sizeXXS ta_controllerId">{{:history.controllerId}}</div>
# 					</div>
# 					<div class="u-grid u-marginTopXS">
# 						<div class="u-width6/12">
# 							<div class="o-copy o-copy--bold o-copy--sizeXXS">
# 								{{:history.decision}}
# 							</div>
# 						</div>
# 						<div class="u-width6/12">
# 							<div class="o-copy o-copy--bold o-copy--sizeXXS">
# 								{{:history.date}}
# 							</div>
# 						</div>
# 						{{for history.decisions}}
# 						<div class="u-width6/12">
# 							<div class="o-copy o-copy--sizeXXS">
# 								{{:decision}}
# 							</div>
# 						</div>
# 						<div class="u-width6/12">
# 							<div class="o-copy o-copy--sizeXXS">
# 								{{:date}}
# 							</div>
# 						</div>
# 						{{/for}}
# 					</div>
# 				</div>
# 				{{/if}}
# 			</div>
# 		</div>
# 	</div>
# </div>
#   </script>
#   <script data-mms-jsrender-tpl="jsrTmplShopSelection" type="text/x-jsrender">
#    <a href="#Shops" class="c-metaNavigation__link" data-ds-metanavigationitem-toggle>
# <div class="c-metaNavigation__icon">
# <span class="c-metaNavigation__iconImage c-metaNavigation__iconImage--shops"></span>
# </div>
# <div class="c-metaNavigation__label">Shops</div>
# </a>
# <div class="c-metaNavigation__flyout" data-ds-metanavigation-flyout>
# <div class="c-compactFlyout c-compactFlyout--sizeS" data-ds-compactflyout tabindex="-1">
# <div class="c-compactFlyout__inner">
# <div class="c-compactFlyout__content">
# <div class="c-compactShoplist ta_header_shopSelection">
# <div class="c-compactShoplist__regions">
# <p class="o-copy o-copy--bold o-copy--sizeS c-compactShoplist__title">
# Sprache &auml;ndern
# </p>
# {{for links}}
# {{if !selected}}
# <div class="c-compactShoplist__linkContainer">
# <a class="c-compactShoplist__link ta_shopselection_{{>countryCode}}_{{>locale}}" href="{{>href}}" data-mms-shopselection-hreflang="{{>hreflang}}">
# <div class="o-svg o-svg--sizeS o-svg--flag{{>countryCode}} c-compactShoplist__flag"></div>
# <p class="o-copy o-copy--sizeS c-compactShoplist__label">
# {{>countryName}} / {{>lang}}
# </p>
# </a>
# </div>
# {{/if}}
# {{/for}}
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#   </script>
#   <script data-mms-jsrender-tpl="jsrTmplShopSelectionMobile" type="text/x-jsrender">
#    <div class="c-accordionShoplist">
# <ul class="c-accordionShoplist__list">
# <li data-ds-collapsable class="c-accordionShoplist__listItem">
# <a data-ds-collapsable-toggle class="c-accordionShoplist__listLink" href="#">
# <div class="o-svg o-svg--sizeS o-svg--flag{{>currentCountryCode}} c-accordionShoplist__listIcon"></div>
# <span>Weitere Shops</span>
# </a>
# <div data-ds-collapsable-content class="c-accordionShoplist__inner">
# {{if links && links.length}}
# <ul class="c-accordionShoplist__list">
# {{for links}}
# {{if selected != true}}
# <li class="c-accordionShoplist__listItem">
# <a class="c-accordionShoplist__listLink ta_shopselection_{{>countryCode}}_{{>locale}} jsCountrySelectLink" href="{{>href}}" data-mms-shopselection-hreflang="{{>hreflang}}">
# <div class="o-svg o-svg--sizeS o-svg--flag{{>countryCode}} c-accordionShoplist__listIcon"></div>
# <span>{{>countryName}} / {{>lang}}</span>
# </a>
# </li>
# {{/if}}
# {{/for}}
# </ul>
# {{/if}}
# </div>
# </li>
# </ul>
# </div>
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/js/content/EXTERNAL_WIDGET_FITANALYTICS.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/lib/js/allinone-foot.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/js/content/EXTERNAL_WIDGET_FITANALYTICS.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/js/content/INTERNAL_WIDGET_LOGINMODAL.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/js/content/GENERAL_DELIVERY_PREDICTIONS.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.arp.shadow.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.usercentrics.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.tracking.datalayer.legacy.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.tracking.fashionapp.controller.legacy.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/js/mms.elk.legacy.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/js/mms.fitfinder.session.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.tracking.econdatracker.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.tracking.econda.campaign.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/base/build/min/js/mms.tracking.exactagcore.js">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/dist/js/production-core.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/dist/js/production-soliver.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/lib/js/allinone-ov.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    //<!--
# /* <![CDATA[ */
# function trackPage() {
#     try{
#         var trackingUrl = "https://www.soliver.de/on/demandware.store/Sites-soliverDE-Site/de_DE/__Analytics-Start";
#         var dwAnalytics = dw.__dwAnalytics.getTracker(trackingUrl);
#         if (typeof dw.ac == "undefined") {
#             dwAnalytics.trackPageView();
#         } else {
#             dw.ac.setDWAnalytics(dwAnalytics);
#         }
#     }catch(err) {};
# }
# /* ]]> */
# // -->
#   </script>
#   <script async="async" onload="trackPage()" src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/internal/jscript/dwanalytics-22.2.js" type="text/javascript">
#   </script>
#   <script async="async" src="/on/demandware.static/Sites-soliverDE-Site/-/de_DE/v1656369202142/internal/jscript/dwac-21.7.js" type="text/javascript">
#   </script>
#   <script async="async" src="https://cdn.cquotient.com/js/v2/gretel.min.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# Wir extraieren den gesamten Text aus der Seite 
print(soup.get_text())
# Out:
# Damen Schuhe im Sale bei s.Oliver: Reduzierte Schuhe für Damen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s.Oliver X Special Olympics Deutschland    Mehr erfahren
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Damen
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
#
#
#
#
# Brand Neu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bekleidung
#
#
#
#
#
#
#
#
# Bekleidung
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kleider
#
#
#
#
#
#
#
#
#
#
#
# Blusen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker
#
#
#
#
#
#
#
#
#
#
#
# Sandalen & Pantoletten
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Accessoires
#
#
#
#
#
#
#
#
# Accessoires
#
#
#
#
#
#
#
#
#
#
#
#
# Echtschmuck
#
#
#
#
#
#
#
#
#
#
#
# Taschen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Düfte & Pflege
#
#
#
#
#
#
#
#
# Düfte & Pflege
#
#
#
#
#
#
#
#
#
#
#
#
# Düfte
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Marken
#
#
#
#
#
#
#
#
# Marken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
#
#
#
#
#
#
# Decken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Geschenkkarte
#
#
#
#
# Inspiration
#
#
#
#
#
#
#
#
# Inspiration
#
#
#
#
#
# Stories
#
#
#
#
#
# Leben im Zentrum
#
#
#
#
#
#
#
#
#
#
# Trends
#
#
#
#
#
#
#
#
#
#
#
#
#
# Festliche Looks
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
#
#
#
#
# Shirts & Tops
#
#
#
#
#
#
#
#
#
#
#
# Kleider
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Herren
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
#
#
#
#
# Brand Neu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bekleidung
#
#
#
#
#
#
#
#
# Bekleidung
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hemden
#
#
#
#
#
#
#
#
#
#
#
# Bermudas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker
#
#
#
#
#
#
#
#
#
#
#
# Boots & Stiefel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Accessoires
#
#
#
#
#
#
#
#
# Accessoires
#
#
#
#
#
#
#
#
#
#
#
#
# Mützen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Düfte
#
#
#
#
#
#
#
#
# Düfte
#
#
#
#
#
#
#
#
#
#
#
#
# Düfte & Pflege
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Marken
#
#
#
#
#
#
#
#
# Marken
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
#
#
#
#
#
#
# Bettwäsche
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Geschenkkarte
#
#
#
#
# Inspiration
#
#
#
#
#
#
#
#
# Inspiration
#
#
#
#
#
# Stories
#
#
#
#
#
# Leben im Zentrum
#
#
#
#
#
#
#
#
#
#
# Trends
#
#
#
#
#
#
#
#
#
#
#
#
#
# Summer in the city
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
#
#
#
#
# Strick & Sweats im SALE
#
#
#
#
#
#
#
#
#
#
#
# Jacken & Mäntel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Junior
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
# New
#
#
#
#
#
#
#
#
#
#
#
#
# Mädchen(Größen 92-176)
#
#
#
#
#
#
#
#
#
#
#
# Jungen(Größen 92-176)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Mädchen
#
#
#
#
#
#
#
#
# Mädchen
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kids(Gr. 92-140)
#
#
#
#
#
#
#
#
#
#
#
# Teens(Gr. 134-176)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jungen
#
#
#
#
#
#
#
#
# Jungen
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kids(Gr. 92-140)
#
#
#
#
#
#
#
#
#
#
#
# Teens(Gr. 134-176)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Babys
#
#
#
#
#
#
#
#
# Babys
#
#
#
#
#
#
#
#
#
#
#
#
#
# Mädchen(62-92)
#
#
#
#
#
#
#
#
#
#
#
# Jungen(62-92)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
# Schuhe
#
#
#
#
#
#
#
#
#
#
#
#
# Mädchen
#
#
#
#
#
#
#
#
#
#
#
# Jungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kinderzimmer
#
#
#
#
#
#
#
#
# Kinderzimmer
#
#
#
#
#
#
#
#
#
#
#
#
# Babyausstattung
#
#
#
#
#
#
#
#
#
#
#
# Bettwäsche
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
# Sale
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SALE Styles für Mädchen
#
#
#
#
#
#
#
#
#
#
#
# SALE Styles für Jungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Mein Konto
#
#
#
#
#
#
#
#
#
#
#
#
# Jetzt anmelden
#
#
#
#
#
#
#
#
#
# Wunschliste
#
#
#
#
#
#
#
#
#
#
#
#
# Warenkorb
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Damen
#
#
#
#
# Herren
#
#
#
#
# Junior
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Summer Sale: bis zu 30% Rabatt auf deine Sommer-Favoriten!
#
#
# Jetzt viele Summer-Styles bis zu 30% Rabatt auf deine Sommer-Favoriten!
#
#
#
#
# Damen
#
#
# Herren
#
#
# Junior
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Bis zu 30%: Der Summer Sale startet jetzt!
#
#
#
#
# Entdecke deine neuen Favoriten im Sommer Sale. Jetzt bis zu 30% auf Shorts, Shirts und vieles mehr.
#
#
#
#
#
#
# Damen – Sale
#
#
#
#
# Herren – Sale
#
#
#
#
# Junior – Sale
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schön, dass du da bist!
#
#
#
# Jetzt anmelden
#
#
#
#
#
#
#
#
#
#
#
#
# Damen
#
#
#
#
#
#
#
#
# Herren
#
#
#
#
#
#
#
#
# Junior
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schuhe
#
#
# (189 Artikel)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sortierung:
#
#
# Bestseller
#
#
#
#
#
#
# Bestseller
#
#
# Beste Ergebnisse
#
#
# Neuheiten
#
#
# Preis aufsteigend
#
#
# Preis absteigend
#
#
#
#
#
#
# Größe
#
#
# Farbe
#
#
# Marke
#
#
#
#
# Alle Filter
#
#
#
#
#
#
#
#
#
# Alle Filter zurücksetzen
#
#
#
#
#
#
#
#
#
#
#
# Artikel filtern
#
#
#
#
#
#
#
#
#
# Größe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schuhgrößen
#
#
#
#
#
#
#
#
#
# 36
#
#
#
#
#
#
#
#
#
#
#
# 37
#
#
#
#
#
#
#
#
#
#
#
# 38
#
#
#
#
#
#
#
#
#
#
#
# 39
#
#
#
#
#
#
#
#
#
#
#
# 40
#
#
#
#
#
#
#
#
#
#
#
# 41
#
#
#
#
#
#
#
#
#
#
#
# 42
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weiß
#
#
#
#
#
#
#
#
#
#
#
#
# creme
#
#
#
#
#
#
#
#
#
#
#
#
# gelb
#
#
#
#
#
#
#
#
#
#
#
#
# orange
#
#
#
#
#
#
#
#
#
#
#
#
# rot
#
#
#
#
#
#
#
#
#
#
#
#
# pink
#
#
#
#
#
#
#
#
#
#
#
#
# lila
#
#
#
#
#
#
#
#
#
#
#
#
# blau
#
#
#
#
#
#
#
#
#
#
#
#
# grün
#
#
#
#
#
#
#
#
#
#
#
#
# olive
#
#
#
#
#
#
#
#
#
#
#
#
# beige
#
#
#
#
#
#
#
#
#
#
#
#
# braun
#
#
#
#
#
#
#
#
#
#
#
#
# grau
#
#
#
#
#
#
#
#
#
#
#
#
# schwarz
#
#
#
#
#
#
#
#
#
#
#
#
# silber
#
#
#
#
#
#
#
#
#
#
#
#
# gold
#
#
#
#
#
#
#
#
#
#
#
#
# bunt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preis
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 22 - 96 EUR
#
#
#
#
#
#
# von
#
#
#
#
# EUR
#
#
#
#
#
# bis
#
#
#
#
#
#
# bis
#
#
#
#
# EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Marke
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# s.Oliver
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Muster
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Animalprint
#
#
#
#
#
#
#
#
#
#
#
#
# Karos
#
#
#
#
#
#
#
#
#
#
#
#
# Colourblocking
#
#
#
#
#
#
#
#
#
#
#
#
# Rundummuster
#
#
#
#
#
#
#
#
#
#
#
#
# Schmucksteine
#
#
#
#
#
#
#
#
#
#
#
#
# Streifen
#
#
#
#
#
#
#
#
#
#
#
#
# Strukturiert
#
#
#
#
#
#
#
#
#
#
#
#
# Unifarben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Artikel anzeigen
#
#
#
# Schließen
#
#
#
# Filter zurücksetzen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -9%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 36,
# 37,
# 38,
# 39,
# 40,
# 41
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Nieten-Besatz
#
#
#
#
# 49,95 EUR
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -9%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 36,
# 37,
# 38,
# 39,
# 40,
# 41
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Nieten-Besatz
#
#
#
#
# 49,95 EUR
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -8%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 37,
# 38,
# 39,
# 40,
# 41
#
#
#
#
#
#
#
#
#
# Sandalen mit Keilabsatz
#
#
#
#
# 59,95 EUR
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -8%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 38,
# 39,
# 41
#
#
#
#
#
#
#
#
#
# Sandalen mit Keilabsatz
#
#
#
#
# 59,95 EUR
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -16%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 36,
# 37,
# 39
#
#
#
#
#
#
#
#
#
# Lederslipper mit Quasten
#
#
#
#
# 59,95 EUR
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -8%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 37,
# 39,
# 40
#
#
#
#
#
#
#
#
#
# Sandalen mit Keilabsatz
#
#
#
#
# 59,95 EUR
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -9%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 37,
# 38
#
#
#
#
#
#
#
#
#
# Sandalen mit Blockabsatz
#
#
#
#
# 49,95 EUR
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -8%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 38,
# 41
#
#
#
#
#
#
#
#
#
# Sandalen aus Echtleder
#
#
#
#
# 59,95 EUR
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -17%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 39
#
#
#
#
#
#
#
#
#
# Zehentrenner-Sandalen aus Leder
#
#
#
#
# 39,95 EUR
#
#
# 32,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -28%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 40,
# 41
#
#
#
#
#
#
#
#
#
# Plateau-Sneaker im Fabric-Mix
#
#
#
#
# 69,95 EUR
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sommerliche Anlässe: Entdecke unsere neuen Kleider für besondere Anlässe mit grenzenlosen Styling-Optionen - so kannst du dich als Gast ganz authentisch in Schale werfen.
#
#
# Jetzt shoppen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -8%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 37,
# 38
#
#
#
#
#
#
#
#
#
# Sandalen aus Echtleder
#
#
#
#
# 59,95 EUR
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -17%
#
#
#
#
#
#
#
#
#
#
# Verfügbar in:
#
#
#
#
# 37
#
#
#
#
#
#
#
#
#
# Ballerinas im Oktoberfest-Look
#
#
#
#
# 39,95 EUR
#
#
# 32,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Farbe
#
#
# Farben
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Plateausohle
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen mit Keilabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ballerinas im Oktoberfest-Look
#
#
#
#
# 32,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zehentrenner-Sandalen aus Leder
#
#
#
#
# 32,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Keil-Sandalen im Fabric-Mix
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen aus Echtleder
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker im Fabric-Mix
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Keil-Sandalen im Fabric-Mix
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Plateausandalen in Metallic-Optik
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leichte Sneaker aus Textil
#
#
#
#
# 29,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker im Fabric-Mix
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Metallic-Schnürer im Brogue-Look
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen aus Leder
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chelsea Boots in Veloursleder-Optik
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ledersandalen mit Schmucksteinen
#
#
#
#
# 39,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker aus Veloursleder
#
#
#
#
# 59,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Riemchen-Sandaletten mit Keilabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wedges im Materialmix
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wedges im Materialmix
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunky Sneaker im Materialmix
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen aus Leder
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Riemchen-Sandaletten mit Keilabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Riemchensandalen in Leder-Optik
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Keilabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Keilabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Echtleder-Sandalen mit Nieten
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Riemchen-Sandalen aus Echtleder
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stiefel in Veloursoptik
#
#
#
#
# 69,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen aus Leder
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker aus Veloursleder
#
#
#
#
# 59,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen mit Blockabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Riemchen-Sandalen aus Echtleder
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen in Reptilleder-Optik
#
#
#
#
# 44,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sandalen mit Blockabsatz
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Kunstleder-Sandalen mit Blockabsatz
#
#
#
#
# 32,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ledersandalen mit Schmucksteinen
#
#
#
#
# 39,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Riemchen
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Raffung
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Boots in Glattleder-Optik
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zehentrenner-Sandalen aus Leder
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Boots in Lackleder-Optik
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stiefeletten aus Veloursleder
#
#
#
#
# 69,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Stiefeletten aus Veloursleder
#
#
#
#
# 69,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Knitwear Sneakers
#
#
#
#
# 45,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sneaker mit Metallic-Detail
#
#
#
#
# 31,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sandalen mit Riemchen
#
#
#
#
# 54,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leder-Sneaker im cleanen Look
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Boots in Lackleder-Optik
#
#
#
#
# 49,99 EUR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
#
#
# 2
#
#
# 3
#
#
# 4
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jetzt kommen die schönsten Schuhe für Damen im Sale!
#
#
# Mit den Schuhen für Damen ist es genauso wie mit der Shopping Bag und
#
# langen Shirts
#
# mit V-Ausschnitt. Farben wirken unterschiedlich und so hat Marine Blau wiederum eine andere Ausstrahlung als Dark Blue und ein schicker Pumps ist eben kein Peep Toe. Der s.Oliver Online-Shop bietet Ihnen tolle Schuhe für Damen im Sale, die sich für den Business Alltag eignen, perfekt zum Casual Style am Nachmittag passen oder eine faszinierende Abendgarderobe komplettieren. Schuhe sorgen für viel Abwechslung in der Garderobe und lassen sich zu unzähligen Variationen im individuellen Style kombinieren.
#
#
# Für jeden Tag ein Paar Schuhe
#
#
# Jeder Anlass benötigt einen unterschiedlichen Schuh. Insbesondere elegante Damenbekleidung beansprucht gute Schuhe mit Wow-Effekt und einem komfortablen Stil. So können Pumps und High Heels auch für viele Stunden am Abend getragen werden. Damit die Alltagsgarderobe nicht nur in Hosen und Kleidern variiert, sind Schuhe für Damen im Sale die ideale Möglichkeit, jedes Outfit mit einem flotten Extra zu versehen. Beim Einkauf oder einem gemütlichen Spaziergang sind Slipper und Halbschuhe perfekt, um die Zeit zu genießen. Stöbern und entdecken Sie die schönsten Schuhe im Sale im s.Oliver Online-Shop.
#
#
#
#
# … mehr anzeigen
#
#
# … weniger anzeigen
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wir helfen dir
#
#
#
#
#
#
# Kontakt
#
#
#
#
# Hilfe & FAQ
#
#
#
#
# Größenberatung
#
#
#
#
# Lob & Kritik
#
#
#
#
# Hygiene- und Sicherheitsmaßnahmen
#
#
#
#
# #standwithukraine
#
#
#
#
# Special Olympics Deutschland
#
#
#
#
#
#
#
#
#
#
#
# Über s.Oliver
#
#
#
#
#
#
# Newsletter
#
#
#
#
# s.Oliver Card
#
#
#
#
# Geschenkkarte
#
#
#
#
# Bankverbindung
#
#
#
#
# s.Oliver Group
#
#
#
#
# Career
#
#
#
#
# s.Oliver App
#
#
#
#
# Wunschliste
#
#
#
#
# WE CARE - Nachhaltigkeit
#
#
#
#
#
#
#
#
#
#
#
# Sicher zahlen
#
#
#
#
#
#
# Rechnung
#
#
#
#
# Vorkasse
#
#
#
#
# Nachnahme
#
#
#
#
# Kreditkarte
#
#
#
#
#  Paypal
#
#
#
#
# Sofortüberweisung
#
#
#
#
# SSL-Verschlüsselung
#
#
#
#
#
#
#
#
#
#
#
# Versand
#
#
#
#
#
#
# Sendungsverfolgung
#
#
#
#
# DHL (0,99 EUR)
#
#
#
#
# Hermes (0,99 EUR)
#
#
#
#
# DHL Express (7,99 EUR)
#
#
#
#
# DHL Packstation
#
#
#
#
# Hermes Paketshop
#
#
#
#
# s.Oliver Filiale
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Vorkasse
#
#
# Rechnung
#
#
# Nachnahme
#
#
#
#
#
# Impressum
#
#
#
#
# Datenschutz
#
#
#
#
# Datenschutz-Einstellungen
#
#
#
#
# AGB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wir sind für dich da!
#
#
#
#
#
#
# Unsere Service-Hotlines sind von Montag bis Freitag von 08:00 bis 20:00 Uhr und samstags von 08:00 bis 18:00 Uhr für dich besetzt.
#
#
#
#
#
#
# Live Chat
#
#
#
#
#
#
# Ruf uns an
# 09302 98 00 101
#
#
#
#
#
#
# Whats App
# 0151 422 193 39
#
#
#
#
#
#
# Mail
# onlineshop@soliver.com
#
#
#
#
#
#
# Kontaktformular
#
#
#
#
#
#
# Häufigste Fragen
#
#
#
#
#
#
#
#
#
#
#
#
# Kontakt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Einen Moment bitte, gleich geht's weiter
#
#
#
#
#
#
#
# Fehler
#
#
#
# SCHLIESSEN
#
#
#
#
#
#
#
#
# Nein
#
#
# Ja
#
#
#
#
#
#
#
#
#
# Weiter

# %%
# Titel: 
soup.title
# Out:
# <title>Damen Schuhe im Sale bei s.Oliver: Reduzierte Schuhe für Damen</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
# Nur den Text/String des Titels: 
soup.title.string
# Out:
# 'Damen Schuhe im Sale bei s.Oliver: Reduzierte Schuhe für Damen'

# %%
# In welchem Tag steht der Tag title: 
soup.title.parent.name
# Out:
# 'meta'

# %%
# Zeigt ersten Hyperlink an 
soup.a
# Out:
# <a class="jsClickTrack" data-clicktracking='{"econda": {"target": {"group": "Promotion Bar", "name": "BAR_INFO_SPECIALOLYMPICS: LP_SPECIALOLYMPICS", "value": 1, "calc": "a"}}}' href="https://www.soliver.de/special-olympics-LP_SPECIALOLYMPICS.html">
# <ul class="c-list c-list--horizontal">
# <li class="c-list__item">
# <div class="c-list__itemContent">
# <p class="o-copy o-copy--sizeXS">
# <span>s.Oliver X Special Olympics Deutschland    <u>Mehr erfahren</u></span>
# </p>
# </div>
# </li>
# </ul>
# </a>

# %%
# Wir bekomme nichts zu sehen, da es in Script geschrieben ist 
soup.span.text
# Out:
# ''

# %% [markdown]
# Der eigentlich wichtige Teil:
# Scrapen der Webseite, um Informationen über den Namen, den Originalpreis und den reduzierten Preis zu bekommen:

# %%
# mti find_all können wir die Datenstruktur nach bestimmten Tags und Klassen durchsuchen 

originalpreis = soup.find_all('span', {'class': 'o-copy o-copy--sizeS o-copy--responsive c-productPanel__priceWas ta_oldPrice'})

# %%
# wir erstellen eine Laufvariable a und lassen diese in soup.find.all durchlaufen. 
# Jedes Mal wenn i diese Klasse findet, nimmt sie den Wert an und fügt den text in die originalliste hinzu
a =0
originalpreisliste= []
while a<5:
    originalpreis = soup.find_all("span", class_="o-copy o-copy--sizeS o-copy--responsive c-productPanel__priceWas ta_oldPrice") [a]

    # Diesen Schritt müssen wir machen, damit wir die Escape-Sequnez des Strings entfernen.
    originalpreis = originalpreis.text.replace ("\n", "")
    a = a+1
    originalpreisliste.append(originalpreis)

# %%
originalpreisliste
# Out:
# ['49,95 EUR', '49,95 EUR', '59,95 EUR', '59,95 EUR', '59,95 EUR']

# %%
name = soup.find_all('p', {'class': 'o-copy o-copy--sizeS o-copy--responsive c-productPanel__name ta_shortdesc'})

# %%
a =0
nameliste= []
while a<5:
    name = soup.find_all("p", class_="o-copy o-copy--sizeS o-copy--responsive c-productPanel__name ta_shortdesc") [a]
    name = name.text.replace ("\n", "")
    a = a+1
    nameliste.append(name)

# %%
nameliste
# Out:
# ['Leder-Sandalen mit Nieten-Besatz',
#  'Leder-Sandalen mit Nieten-Besatz',
#  'Sandalen mit Keilabsatz',
#  'Sandalen mit Keilabsatz',
#  'Lederslipper mit Quasten']

# %%
aktuellerPreis = soup.find_all('span', {'class': 'o-copy o-copy--sizeS o-copy--responsive o-copy--bold c-productPanel__priceSale ta_newPrice'})

# %%
a =0
aktuellePreiliste= []
while a<5:
    aktuellerPreis = soup.find_all("span", class_="o-copy o-copy--sizeS o-copy--responsive o-copy--bold c-productPanel__priceSale ta_newPrice") [a]
    aktuellerPreis = aktuellerPreis.text.replace ("\n", "")
    a = a+1
    aktuellePreiliste.append(aktuellerPreis)

# %%
aktuellePreiliste
# Out:
# ['44,99 EUR', '44,99 EUR', '54,99 EUR', '54,99 EUR', '49,99 EUR']

# %%
# Wir erstellen ein DataFrame und eine CSV, damit unsere Kollgen weitere Analysen durchführen können
df = pd.DataFrame (
    {"originalpreis":originalpreisliste,
    "aktuellerpreis":aktuellePreiliste,
    "name":nameliste})

# %%
df
# Out:
#   originalpreis aktuellerpreis                              name
# 0     49,95 EUR      44,99 EUR  Leder-Sandalen mit Nieten-Besatz
# 1     49,95 EUR      44,99 EUR  Leder-Sandalen mit Nieten-Besatz
# 2     59,95 EUR      54,99 EUR           Sandalen mit Keilabsatz
# 3     59,95 EUR      54,99 EUR           Sandalen mit Keilabsatz
# 4     59,95 EUR      49,99 EUR          Lederslipper mit Quasten

# %%
df.to_csv("/Users/rafaela/test/Webscraping.csv")
